# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
import sys
import json
from pathlib import Path
import pandas as pd
import numpy as np
import random as rnd
import dedupe
import logging
import datetime
from dotenv import find_dotenv, load_dotenv
import dotenv
import requests
from urllib.parse import urljoin
import subprocess

import backtester
from ers_experimenter import ERSExperiment
import utils

log_fmt = f'%(asctime)s - %(levelname)s - %(message)s'
logging.basicConfig(stream=sys.stdout, level=logging.INFO, format=log_fmt, datefmt='%Y-%m-%dT%H:%M:%S')
logging.getLogger("requests").setLevel(logging.WARNING)
logging.getLogger("urllib3").setLevel(logging.WARNING)
logging.info('Go head')

load_dotenv(find_dotenv())
# Out:
# INFO:root:Generating grammar tables from /usr/lib/python3.6/lib2to3/Grammar.txt
# INFO:root:Generating grammar tables from /usr/lib/python3.6/lib2to3/PatternGrammar.txt
# INFO:root:Go head
# True

# %%
def check_to_create_company_entry(company):
    result = False
    matching_ers_ids = []
    
    url = os.environ["ERS_BASEURI"] + '/crud_service/matchCompany'
    response = requests.post(url, json=company)
    if response.status_code == 200:
        matches = response.json()

        if len(matches) == 0:
            result = True
        else:
            matching_ers_ids = matches
        
    elif response.status_code == 500:
        if response.text.find('but maxThreshold is') > 0:
            logging.info(f'For {company} found too ambiguous entries!')
        else:
            logging.warning(f'Got some unkown 500 error: {response.text}. The problem ocurred '
                        f'for record {company}.')
    else:
        logging.warning(f'ERS responded with unexpected status {response.status_code}. The problem ocurred '
                        f'for record {company}.')
        
    return result, matching_ers_ids


def create_company(company):
    url = os.environ["ERS_BASEURI"] + '/crud_service/createCompany'

    response = requests.post(url, json=company)
    if response.status_code != 201:
        logging.warning(f"Couldnt create company entry for {company['crmId']}. ERS replied: {response.text}")

                        
def get_infos_about_company(ers_id):
    url = os.environ["ERS_BASEURI"] + '/crud_service/getCompanyById'
    response = requests.get(url, {'idType':'ERS_ID', 'id':ers_id})
    if response.status_code != 200:
        logging.warning(f'Could not get infos about {ers_id} due to {response.text}')
    else:
        infos = json.loads(response.text)
        if len(infos) == 1:
            return infos[0]
        else:
            logging.warning(f'Returned infos about company {ers_id} was given in unexpected format. Raw response of ERS was: {response.text}')
            return None
        
                    
def compile_infos_about_duplicates(duplicates):
    if len(duplicates) == 0:
        return pd.DataFrame()
                        
    crm_infos_about_duplicates = []
    ers_infos_about_duplicates = []
    for duplicate in duplicates:
        crm_infos_about_duplicates.append({**{'crmId_from_imported_file':duplicate['crmId']}, **crm_data.loc[duplicate['crmId']].reindex(['name','address.street', 'address.city', 'address.zip']).to_dict()})
        base_infos = {'ersId':duplicate['ersId'], 'probability':duplicate['probability']}
        
        ers_infos = get_infos_about_company(duplicate['ersId'])        
        if ers_infos is not None:
            base_infos['ers_name'] = ers_infos.get('name')
            base_infos['crmId_known_to_ERS'] = ers_infos.get('crmId')
            address_infos = ers_infos.get('residentAddressSet')
            if (address_infos is not None) and len(address_infos) >= 1:
                base_infos['ers_street'] = address_infos[0]['address'].get('street')
                base_infos['ers_city'] = address_infos[0]['address'].get('city')
                base_infos['ers_zip'] = address_infos[0]['address'].get('zip')
                
        ers_infos_about_duplicates.append(base_infos)
        
    crm_infos_about_duplicates = pd.DataFrame.from_records(crm_infos_about_duplicates)
    ers_infos_about_duplicates = pd.DataFrame.from_records(ers_infos_about_duplicates)
    result = pd.concat([crm_infos_about_duplicates, ers_infos_about_duplicates], axis=1).fillna('')
    return result[['crmId_from_imported_file', 'crmId_known_to_ERS', 'ersId', 'probability', 'name', 'ers_name', 'address.city', 'ers_city', 'address.street', 'ers_street', 'address.zip', 'ers_zip']]
        

def load_crm_data_into_ers(crm_data):
    experimenter = ERSExperiment()
    
    duplicates = []
    for i, record in enumerate(crm_data.reset_index().to_dict(orient='records')):
        if (i % 1000) == 0:
            logging.info(f'Processing {i}th of {len(crm_data)} entries.')

        try:
            company = experimenter._transform_crm_record_to_company_object(record, information_source=str(crm_filename))

            crm_id = company.pop('crmId')
            is_safe_to_create, matches = check_to_create_company_entry(company)
            if is_safe_to_create:
                company['crmId'] = crm_id
                create_company(company)
            else:
                for match in matches:
                    duplicates.append({'crmId':crm_id, **match})
                logging.warning(f'Found duplicate for CRM Id {crm_id}: {matches}')

        except Exception as e:
            logging.error(f'Exception during calling createCompany: {e}')
                        
    logging.info('Done with loading {len(crm_data)} company entries.')
    return compile_infos_about_duplicates(duplicates)

# %% [markdown]
# # Loading the raw data

# %%
ls $DATA_PATH/raw/crefo_cleaning
# Out:
# 11761_3.xlsx  csprod_companies__2018_12_05.csv
# 11761_4.xlsx  csprod_companies__2018_12_05_edited.csv
# 11761_5.xlsx  ~$11761_5.xlsx

# %%
MAP_CRM_TO_ERS_COLUMNS = {'id':'crmId', 'buergel_id':'buergelId', 'name':'name', 'legal_form':'legalForm',
                               'hq_email':'email', 'hq_phone':'phoneNumber', 'website':'website',
                               'taxid':'vatID', 'register_number':'registerNumber', 'local_court':'commercialRegister',
                               'hq_street':'address.street', 'hq_zip_code':'address.postalCode',
                               'hq_city':'address.city', 'hq_country':'address.country'}

crm_filename = Path(os.environ['DATA_PATH']) / 'raw' / 'crefo_cleaning' / 'csprod_companies__2018_12_05_edited.csv'
crm_data = pd.read_csv(crm_filename, skiprows=[44115, 44950, 49610], dtype={'buergel_id':str, 12:str, 24:str, 33:str})

crm_data = crm_data[list(MAP_CRM_TO_ERS_COLUMNS.keys())]
crm_data.rename(columns=MAP_CRM_TO_ERS_COLUMNS, inplace=True)
crm_data.set_index('crmId', inplace=True)
crm_data[:5]
# Out:
#       buergelId                                      name legalForm email  \
# crmId
# 1      55013451  Bio River Life Science im Rheinland e.V.       NaN   NaN
# 2           NaN            Die Schuhleister GmbH & Co. KG       NaN   NaN
# 3      58088981                              evopark GmbH       NaN   NaN
# 4       3549425                 Stadtsparkasse Düsseldorf       NaN   NaN
# 5           NaN       Verivox Versicherungsvergleich GmbH       NaN   NaN
#
#       phoneNumber                         website vatID registerNumber  \
# crmId
# 1             NaN          http://www.bioriver.de   NaN            NaN
# 2             NaN  http://www.die-schuhleister.de   NaN            NaN
# 3             NaN           http://www.evopark.de   NaN            NaN
# 4      +492118780    http://www.sskduesseldorf.de   NaN          14082
# 5             NaN           http://www.verivox.de   NaN            NaN
#
#       commercialRegister       address.street address.postalCode address.city  \
# crmId
# 1                    NaN  Merowinger Platz 1a              40225   Düsseldorf
# 2                    NaN       Eifelplatz 1-3              50677         Köln
# 3                    NaN    Sedanstraße 31-33              50668         Köln
# 4                    NaN    Berliner Allee 33              40212   Düsseldorf
# 5                    NaN     Am Taubenfeld 10              69123   Heidelberg
#
#       address.country
# crmId
# 1                  DE
# 2                  DE
# 3                  DE
# 4                  DE
# 5                  DE

# %%
# logging.warning('First purging the complete database.')
# _ = requests.post(os.environ["ERS_BASEURI"] + '/aux_service/purgeDatabase')
# Out:
# 11:28:32.011 - WARNING - First purging the complete database.

# %%
# %time duplicates = load_crm_data_into_ers(crm_data[:5])
duplicates.to_pickle(Path(os.environ['DATA_PATH']) / 'processed' / 'crefo_cleaning_duplicates_of_crm.pkl')
# Out:
# 11:37:47.011 - INFO - Processing 0th of 5 entries.
# 11:37:47.011 - INFO - Done with loading {len(crm_data)} company entries.
# CPU times: user 30 ms, sys: 30 ms, total: 60 ms
# Wall time: 665 ms

# %%
duplicates = pd.read_pickle(Path(os.environ['DATA_PATH']) / 'processed' / 'crefo_cleaning_duplicates_of_crm.pkl')

# %%
len(duplicates)
# Out:
# 15

# %%
pwd
# Out:
# '/home/datascientist/host/src/notebooks'

# %%
df = pd.read_excel('/home/datascientist/host/data/raw/crefo_cleaning/11761_3.xlsx')

# %%
len(df)
# Out:
# 44337

# %%
df[:3]
# Out:
#         Crefo Anrede Titel Beteiligter Vorname Beteiligter Nachname  \
# 0  2010000001   Herr   NaN             Manfred                 Otte
# 1  2010000470   Herr   NaN             Norbert                 Kunz
# 2  2010000847   Herr   NaN            Meinhard              Mientus
#
#        Eigenschaft                Firma1                      Firma2  \
# 0  Geschäftsführer     Wiener Conditorei  & Caffeehaus Betriebs-GmbH
# 1  Geschäftsführer   Recke Fleischwaren-     Spezialitäten Vertriebs
# 2  Geschäftsführer  Michael Mientus GmbH                         NaN
#
#           Firma3        Straße/Hausnummer    PLZ     Ort   Telefonnummer  \
# 0            NaN            Reichsstr. 81  14052  Berlin  +49 30 3641060
# 1  GmbH & Co. KG  Beusselstr. 44 n-q/G128  10553  Berlin   +49 30 396030
# 2            NaN    Wilmersdorfer Str. 73  10629  Berlin  +49 30 3239077
#
#                        E-Mail                        URL  neuester Umsatz  \
# 0   info@wiener-conditorei.de   www.wiener-conditorei.de       5575065.63
# 1  info@recke-fleischwaren.de  www.recke-fleischwaren.de      32800000.00
# 2            info@mientus.com            www.mientus.com      15600000.00
#
#    neueste Mitarbeiterzahl  Branchencode  \
# 0                    148.0       1071002
# 1                    115.0         46320
# 2                     60.0       4771002
#
#                                              Branche  Bonitätsklasse
# 0                      Herstellung von Konditorwaren               1
# 1            Großhandel mit Fleisch und Fleischwaren               1
# 2  Einzelhandel mit Herrenbekleidung und Bekleidu...               1

# %%
def join_Firma123(row):
    return " ".join([str(row['Firma1']), str(row['Firma2']), str(row['Firma3'])]).strip()

df.loc[:,['Firma1', 'Firma2', 'Firma3']].fillna('', inplace=True)
df['Firma123'] = df.apply(join_Firma123, axis=1)

# %%
type(df.loc[0,'Firma3'])
# Out:
# float

# %%
MAP_CREFO_TO_ERS_COLUMNS = {'Firma123':'name', 'legal_form':'legalForm',
                               'E-Mail':'email', 'Telefonnummer':'phoneNumber', 'URL':'website',
                               'Straße/Hausnummer':'address.street', 'PLZ':'address.postalCode',
                               'Ort':'address.city'}

# %%
pwd
# Out:
# '/home/datascientist/host/src/notebooks'

# %% [markdown]
# # Work directly w/o Neo4J

# %%
sys.path.append('/home/datascientist/host/creditshelf-entity-recognition-service/src/python/')

# %%
import check_crefo_addresses
# Out:
# 13:58:55.017 [Python MainThread] INFO /home/datascientist/host/creditshelf-entity-recognition-service/src/python/entity_matcher.py::dedupe.api ((SimplePredicate: (sameFiveCharStartPredicate, name), SimplePredicate: (sameThreeCharStartPredicate, name)), (SimplePredicate: (commonFourGram, address.street), SimplePredicate: (nearIntegersPredicate, address.postal_code)))
# 13:58:55.017 [Python MainThread] INFO /home/datascientist/host/creditshelf-entity-recognition-service/src/python/entity_matcher.py::root Loaded dedupe model /home/datascientist/host/src/notebooks/latest.model successfully.

# %%
crm_data = check_crefo_addresses.load_crm_data()
crm_data.set_index('crmId', inplace=True)

# %%
crefo_filemark = '11761_5'

# %%
with open(Path(os.environ['DATA_PATH']) / f'processed/crefo_cleaning_duplicates_of_{crefo_filemark}.json') as f:
    duplicates = json.load(f)
    
len(duplicates)
# Out:
# 549

# %%
def join_Firma123(row):
        return " ".join([str(row['Firma1']), str(row['Firma2']), str(row['Firma3'])]).strip()

crefo_data = pd.read_excel(f'/home/datascientist/host/data/raw/crefo_cleaning/{crefo_filemark}.xlsx')
crefo_data.set_index('Crefo', inplace=True)
crefo_data.loc[:,['Firma1', 'Firma2', 'Firma3']] = crefo_data.loc[:,['Firma1', 'Firma2', 'Firma3']].fillna('')
crefo_data['Firmename'] = crefo_data.apply(join_Firma123, axis=1)
crefo_data['CRM_Id'] = ''
crefo_data['similarity'] = np.NAN
crefo_data['CRM_name'] = ''
crefo_data['CRM_street'] = ''
crefo_data['CRM_zip'] = ''
crefo_data['CRM_city'] = ''

# %%
len(crefo_data)
# Out:
# 4202

# %%
for duplicate in duplicates:
    if len(duplicate['matches']) > 1:
        logging.info(f"Found multiple matches to CRM for entry {duplicate['record']['ers_id']}")

    crefo_id = int(duplicate['record']['ers_id'][6:])
    crefo_data.loc[crefo_id, 'CRM_Id'] = crm_id = int(duplicate['matches'][0][0])
    crefo_data.loc[crefo_id, 'similarity'] = duplicate['matches'][0][1]

    crefo_data.loc[crefo_id, 'CRM_name'] = crm_data.loc[crm_id, 'name']
    crefo_data.loc[crefo_id, 'CRM_street'] = crm_data.loc[crm_id, 'address.street']
    crefo_data.loc[crefo_id, 'CRM_zip'] = crm_data.loc[crm_id, 'address.postal_code']
    crefo_data.loc[crefo_id, 'CRM_city'] = crm_data.loc[crm_id, 'address.city']
# Out:
# 14:19:21.017 [Python MainThread] INFO /home/datascientist/host/creditshelf-entity-recognition-service/src/python/entity_matcher.py::root Found multiple matches to CRM for entry crefo_2151289958
# 14:19:21.017 [Python MainThread] INFO /home/datascientist/host/creditshelf-entity-recognition-service/src/python/entity_matcher.py::root Found multiple matches to CRM for entry crefo_2151308199
# 14:19:22.017 [Python MainThread] INFO /home/datascientist/host/creditshelf-entity-recognition-service/src/python/entity_matcher.py::root Found multiple matches to CRM for entry crefo_5190922618
# 14:19:22.017 [Python MainThread] INFO /home/datascientist/host/creditshelf-entity-recognition-service/src/python/entity_matcher.py::root Found multiple matches to CRM for entry crefo_5230354873
# 14:19:22.017 [Python MainThread] INFO /home/datascientist/host/creditshelf-entity-recognition-service/src/python/entity_matcher.py::root Found multiple matches to CRM for entry crefo_7290153022
# 14:19:22.017 [Python MainThread] INFO /home/datascientist/host/creditshelf-entity-recognition-service/src/python/entity_matcher.py::root Found multiple matches to CRM for entry crefo_7350081773
# 14:19:22.017 [Python MainThread] INFO /home/datascientist/host/creditshelf-entity-recognition-service/src/python/entity_matcher.py::root Found multiple matches to CRM for entry crefo_8170986837

# %%
crefo_data.reset_index().to_excel(f'/home/datascientist/host/data/processed/{crefo_filemark}_with_matches_to_CRM.xlsx')

# %%
duplicates_with_infos = crefo_data[crefo_data.CRM_Id != ''][['CRM_Id', 'similarity', 'Firmename', 'CRM_name', 'Straße/Hausnummer', 'CRM_street', 'PLZ', 'CRM_zip', 'Ort', 'CRM_city']]

# %%
print('Done!')
# Out:
# Done!

# %%
duplicates_with_infos
# Out:
#             CRM_Id  similarity  \
# Crefo
# 2010033498   79190    0.793675
# 2010080652   88160    0.820786
# 2010129387   89202    0.912569
# 2010246038   87674    0.936011
# 2010345289   88670    0.890699
# 2010458087   90365    0.932553
# 2010577693   88156    0.567181
# 2010732190   90695    0.814701
# 2010796332   87409    0.808390
# 2010797599   90638    0.509127
# 2010955426   90694    0.923253
# 2011087184   87059    0.790611
# 2011224990   88937    0.769069
# 2011305602   23052    0.930701
# 2011377758   86351    0.916786
# 2011430844   47478    0.935773
# 2011505849   87462    0.607215
# 2011564224   62684    0.892000
# 2011696156   86545    0.891421
# 2011942653   88954    0.906623
# 2011985453  118039    0.793652
# 2012111131  118238    0.889534
# 2012179520   71439    0.895106
# 2012184966   87910    0.910611
# 2012335524  101088    0.819890
# 2012401886   72331    0.916647
# 2012442200   62697    0.753187
# 2012541568   79487    0.785824
# 2012612589   65505    0.807806
# 2030006184   96911    0.638611
# ...            ...         ...
# 8250263274   15596    0.845021
# 8250322456   14718    0.897623
# 8250356620   74044    0.942266
# 8250446947   15116    0.788115
# 8270001861   18463    0.916538
# 8270007185   18214    0.765030
# 8270054012   18149    0.839671
# 8270110905   80163    0.926665
# 8270204228   96448    0.935371
# 8270241808   18472    0.755083
# 8270289528   18527    0.924687
# 8270315850   90935    0.914174
# 8290004100   14389    0.942936
# 8290050787   14596    0.638480
# 8290056042   14514    0.936924
# 8290073164   14606    0.928044
# 8290102884   14455    0.940070
# 8290119010   14672    0.742801
# 8290126710   15159    0.941346
# 8290132480   75569    0.920248
# 8290212482   14565    0.932298
# 8290235125   14667    0.932696
# 8310005376   20830    0.702732
# 8310007236   20814    0.889720
# 8310025408   20728    0.942640
# 8310081845   21182    0.916743
# 8310149614   20671    0.913327
# 8310156008   20864    0.947496
# 8310162812   73052    0.909727
# 8310182021    1888    0.822698
#
#                                                     Firmename  \
# Crefo
# 2010033498  TELES Aktiengesellschaft Informationstechnologien
# 2010080652                      Würfel Kunststofftechnik GmbH
# 2010129387                      Oberflächentechnik Kläke GmbH
# 2010246038                    Böger Fassaden Bauelemente GmbH
# 2010345289                          Pneumatik Berlin GmbH PTM
# 2010458087        Linmet Glas-Keramik Handelsgesellschaft mbH
# 2010577693  Basdorf, Lampe & Partner GmbH Formen- und Werk...
# 2010732190                              SCALA Electronic GmbH
# 2010796332                                      Epro Tec GmbH
# 2010797599                                   Seilpartner GmbH
# 2010955426                    Beechcraft Berlin Aviation GmbH
# 2011087184                             Krebs Baubeschlag GmbH
# 2011224990    Indetec GmbH für Innovation, Design und Technik
# 2011305602                                     BIERLINIE GmbH
# 2011377758             Becker Sport- und Freizeitanlagen GmbH
# 2011430844                                Antalis Macron GmbH
# 2011505849                             WELLSTAR GmbH & Co. KG
# 2011564224                                  Back & Frost GmbH
# 2011696156                           GP GmbH GERMAN PETROLIUM
# 2011942653                                Younes Service GmbH
# 2011985453                                      Meetrics GmbH
# 2012111131                   Rubert Straßen- und Tiefbau GmbH
# 2012179520                                   tausendkind GmbH
# 2012184966                                   HT Troplast GmbH
# 2012335524                                 Medici Living GmbH
# 2012401886                                   Ö & I Clean GmbH
# 2012442200                                        Sawade GmbH
# 2012541568                    Electric Mobility Concepts GmbH
# 2012612589                                    Weissmaler GmbH
# 2030006184                       Metallbau Otto Kilimann GmbH
# ...                                                       ...
# 8250263274                         SKW Stahl-Metallurgie GmbH
# 8250322456                                        RESTEC GmbH
# 8250356620  Temme // Obermeier GmbH Experts for Membran Bu...
# 8250446947                         FPS Fertigungstechnik GmbH
# 8270001861                       R. Bayer Betonsteinwerk GmbH
# 8270007185                                       Eugen Rumpel
# 8270054012                                Rommel Energie GmbH
# 8270110905                          Aquasol Solartechnik GmbH
# 8270204228           SKV Sand-Kies-Vertrieb Ulm GmbH & Co. KG
# 8270241808                 I.S.T. Intensiv-Service- Team GmbH
# 8270289528                               akf siemers süd GmbH
# 8270315850                                         S-Tec GmbH
# 8290004100  Dämmstoffe und Energiesparsysteme DEV Vertrieb...
# 8290050787                                Getränke Glasl GmbH
# 8290056042  Rohloff Cosmetics Gesellschaft für Kosmetik Ve...
# 8290073164              Zugspitz-Tiefkühlvertrieb Endreß GmbH
# 8290102884                               DYNAMIC Systems GmbH
# 8290119010                 kc Möbel-Einrichtungs- häuser GmbH
# 8290126710  ERKA Kallmeyer Medizintechnik GmbH & Co. Komma...
# 8290132480                                   More & More GmbH
# 8290212482                             MTP-Metalltechnik GmbH
# 8290235125                              Shvabe - München GmbH
# 8310005376                             Scheuring Fenster GmbH
# 8310007236                                       Vaeplan GmbH
# 8310025408         WEIGANG-Primoris- Organisationsmittel GmbH
# 8310081845                              Versch Baustoffe GmbH
# 8310149614                           Öchsner Agrarhandel GmbH
# 8310156008     Joh. Clouth Maschinenbau Eltmann GmbH & Co. KG
# 8310162812                                  WTL Security GmbH
# 8310182021                       Präzisions-Maschinenbau GmbH
#
#                                                      CRM_name  \
# Crefo
# 2010033498  Teles Aktiengesellschaft Informationstechnologien
# 2010080652                      Würfel Kunststofftechnik GmbH
# 2010129387                      Oberflächentechnik Kläke GmbH
# 2010246038                    Böger Fassaden Bauelemente GmbH
# 2010345289                          Pneumatik Berlin GmbH PTM
# 2010458087        Linmet Glas-Keramik Handelsgesellschaft mbH
# 2010577693  Basdorf Lampe & Partner GmbH Formen- und Werkz...
# 2010732190                              SCALA Electronic GmbH
# 2010796332                                       EproTec GmbH
# 2010797599                         Seilpartner Windkraft GmbH
# 2010955426                    Beechcraft Berlin Aviation GmbH
# 2011087184                             Krebs Baubeschlag GmbH
# 2011224990     Indetec GmbH für Innovation Design und Technik
# 2011305602                                     Bierlinie GmbH
# 2011377758             Becker Sport- und Freizeitanlagen GmbH
# 2011430844                                Antalis Macron GmbH
# 2011505849                             WELLSTAR GmbH & Co. KG
# 2011564224                                  Back & Frost GmbH
# 2011696156                           GP GmbH GERMAN PETROLIUM
# 2011942653                                Younes Service GmbH
# 2011985453                                      Meetrics GmbH
# 2012111131                   Rubert Straßen- und Tiefbau GmbH
# 2012179520                                   Tausendkind GmbH
# 2012184966                                   HT Troplast GmbH
# 2012335524                                 Medici Living GmbH
# 2012401886                                   Ö & I Clean GmbH
# 2012442200                                        Sawade GmbH
# 2012541568                    Electric Mobility Concepts GmbH
# 2012612589                                    Weissmaler GmbH
# 2030006184                       Metallbau Otto Kilimann GmbH
# ...                                                       ...
# 8250263274                         SKW Stahl-Metallurgie GmbH
# 8250322456                                        RESTEC GmbH
# 8250356620  Temme // Obermeier GmbH Experts For Membran Bu...
# 8250446947                         FPS Fertigungstechnik GmbH
# 8270001861                       R. Bayer Betonsteinwerk GmbH
# 8270007185                                       Eugen Rumpel
# 8270054012                                Rommel Energie GmbH
# 8270110905                          AQUASOL Solartechnik GmbH
# 8270204228           SKV Sand-Kies-Vertrieb Ulm GmbH & Co. KG
# 8270241808                  I.S.T. Intensiv-Service-Team GmbH
# 8270289528                               akf siemers süd GmbH
# 8270315850                                         S-Tec GmbH
# 8290004100  Dämmstoffe und Energiesparsysteme DEV Vertrieb...
# 8290050787                                Getränke Glasl GmbH
# 8290056042  Rohloff Cosmetics Gesellschaft für Kosmetik Ve...
# 8290073164              Zugspitz-Tiefkühlvertrieb Endreß GmbH
# 8290102884                               DYNAMIC Systems GmbH
# 8290119010                   kc Möbel-Einrichtungshäuser GmbH
# 8290126710  ERKA Kallmeyer Medizintechnik GmbH & Co. Komma...
# 8290132480                                   More & More GmbH
# 8290212482                             MTP-Metalltechnik GmbH
# 8290235125                              Shvabe - München GmbH
# 8310005376                             Scheuring Fenster GmbH
# 8310007236                                       Vaeplan GmbH
# 8310025408          WEIGANG-Primoris-Organisationsmittel GmbH
# 8310081845                              Versch Baustoffe GmbH
# 8310149614                           Öchsner Agrarhandel GmbH
# 8310156008     Joh. Clouth Maschinenbau Eltmann GmbH & Co. KG
# 8310162812                                  Wtl Security GmbH
# 8310182021                       Präzisions-Maschinenbau GmbH
#
#                         Straße/Hausnummer                  CRM_street    PLZ  \
# Crefo
# 2010033498        Ordensmeisterstr. 15-16        Ernst-Reuter-Platz 8  12099
# 2010080652                 Am Jägerberg 7              Am Jägerberg 7  16727
# 2010129387            Köpenicker Str. 147         Köpenicker Str. 147  10997
# 2010246038                    Dorfstr. 23               Dorfstraße 23  12529
# 2010345289        Falkenberger Str. 38-40        Falkenberger Str. 40  13088
# 2010458087                    Rhinstr. 84                 Rhinstr. 86  12681
# 2010577693   Köpenicker Str. 325 Halle 41         Köpenicker Str. 325  12555
# 2010732190            Ruhlsdorfer Str. 95         Ruhlsdorfer Str. 95  14532
# 2010796332         Brebacher Weg 15 Hs 48            Brebacher Weg 15  12683
# 2010797599            Greifswalder Str. 9         Greifswalder Str. 9  10405
# 2010955426  Elly-Beinhorn-Ring 4 Geb.X064        Elly-Beinhorn-Ring 4  12529
# 2011087184            Köpenicker Str. 145         Köpenicker Str. 145  10997
# 2011224990                Industriestr. 2             Industriestr. 2  14943
# 2011305602              Am Borsigturm 100           Am Borsigturm 100  13507
# 2011377758           Sperenberger Str. 5a        Sperenberger Str. 5A  12277
# 2011430844                 Europaallee 19              Europaallee 19  50226
# 2011505849               Friedrichstr. 95            Charlottenstr. 4  10117
# 2011564224               Schwechtenstr. 5          Schwechtenstraße 3  12277
# 2011696156                  Suarezstr. 19               Suarezstr. 19  14057
# 2011942653               Buckower Damm 34            Buckower Damm 34  12349
# 2011985453                Alexanderstr. 7             Alexanderstr. 7  10178
# 2012111131              Boxberger Str. 15         Boxberger Straße 15  12681
# 2012179520              Knesebeckstr. 1-2           Knesebeckstr. 1-2  10623
# 2012184966            Motzener Str. 31-33         Motzener Str. 31-33  12277
# 2012335524               Zossener Str. 55            Zossener Str. 55  10961
# 2012401886         Straße der Republik 11      Straße Der Republik 11   4571
# 2012442200                  Wittestr. 26e             Wittestraße 26e  13509
# 2012541568               Alboinstr. 17-23            Alboinstr. 17-23  12103
# 2012612589           Prinzessinnenstr. 26        Prinzessinnenstr. 26  10969
# 2030006184                   Steinbrink 8   Friedrich Seele Straße 1b  38122
# ...                                   ...                         ...    ...
# 8250263274                Rathausplatz 11             Rathausplatz 11  84579
# 8250322456           Äußere Oberaustr. 22        Äußere Oberaustr. 20  83026
# 8250356620         Dr.-Steinbeißer-Str. 7      Dr.-Steinbeißer-Str. 7  83026
# 8250446947          Rudolf-Diesel-Ring 10       Rudolf-Diesel-Ring 10  83607
# 8270001861        Dr.-Georg-Spohn-Str. 21     Dr.-Georg-Spohn-Str. 21  89143
# 8270007185                Enhofer Str. 47             Enhofer Str. 47  88515
# 8270054012                 Bergmannstr. 2              Bergmannstr. 2  88471
# 8270110905       Dr.-Carl-Schwenk-Str. 20    Dr.-Carl-Schwenk-Str. 20  89233
# 8270204228                  Magirusstr. 4               Magirusstr. 4  89129
# 8270241808                Industriestr. 9             Industriestr. 9  89150
# 8270289528      Graf-von-Zeppelin-Str. 23  Graf- von Zeppelin-Str. 23  89150
# 8270315850       Dr.-Jungheinrich-Platz 2    Dr.-Jungheinrich-Platz 2   1665
# 8290004100                Frühlingstr. 17             Frühlingstr. 17  82205
# 8290050787                 Friedzaunweg 1             Friedzaunweg 1a  82431
# 8290056042              Heimgartenstr. 26           Heimgartenstr. 26  82319
# 8290073164                   Finkenstr. 9                Finkenstr. 9  82467
# 8290102884               Inninger Str. 11            Inninger Str. 11  82237
# 8290119010                 Sudetenstr. 78               Sudetenstr 78  82538
# 8290126710                  Im Farchet 15               Im Farchet 15  83646
# 8290132480                       Schorn 1                    Schorn 1  82319
# 8290212482             Hochreuther Str. 4          Hochreuther Str. 4  82380
# 8290235125             Königsdorfer Weg 6          Königsdorfer Weg 6  82538
# 8310005376                Gewerbestr. 1-6             Gewerbestr. 1-6  97450
# 8310007236             Augsfelder Str. 20          Augsfelder Str. 20  97437
# 8310025408                      Sandweg 2                   Sandweg 2  97332
# 8310081845                  Am Witzpfad 3               Am Witzpfad 3  97907
# 8310149614                     Ringstr. 6                  Ringstr. 6  97274
# 8310156008               Industriestr. 25            Industriestr. 25  97483
# 8310162812               Raiffeisenstr. 7            Raiffeisenstr. 7  97723
# 8310182021               Raiffeisenstr. 6            Raiffeisenstr. 6  97854
#
#            CRM_zip                     Ort                CRM_city
# Crefo
# 2010033498   10587                  Berlin                  Berlin
# 2010080652   16727                  Velten                  Velten
# 2010129387   10997                  Berlin                  Berlin
# 2010246038   12529              Schönefeld              Schönefeld
# 2010345289   13088                  Berlin                  Berlin
# 2010458087   12681                  Berlin                  Berlin
# 2010577693   12555                  Berlin                  Berlin
# 2010732190   14532              Stahnsdorf              Stahnsdorf
# 2010796332   12683                  Berlin                  Berlin
# 2010797599   10405                  Berlin                  Berlin
# 2010955426   12529              Schönefeld              Schönefeld
# 2011087184   10997                  Berlin                  Berlin
# 2011224990   14943             Luckenwalde             Luckenwalde
# 2011305602   13507                  Berlin                  Berlin
# 2011377758   12277                  Berlin                  Berlin
# 2011430844   50226                 Frechen                 Frechen
# 2011505849   10969                  Berlin                  Berlin
# 2011564224   12277                  Berlin                  Berlin
# 2011696156   14057                  Berlin                  Berlin
# 2011942653   12349                  Berlin                  Berlin
# 2011985453   10178                  Berlin                  Berlin
# 2012111131   12681                  Berlin                  Berlin
# 2012179520   10623                  Berlin                  Berlin
# 2012184966   12277                  Berlin                 Berlin.
# 2012335524   10961                  Berlin                  Berlin
# 2012401886   04571                   Rötha                   Rötha
# 2012442200   13509                  Berlin                  Berlin
# 2012541568   12103                  Berlin                  Berlin
# 2012612589   10969                  Berlin                  Berlin
# 2030006184   38122            Braunschweig            Braunschweig
# ...            ...                     ...                     ...
# 8250263274   84579         Unterneukirchen         Unterneukirchen
# 8250322456   83026               Rosenheim               Rosenheim
# 8250356620   83026               Rosenheim               Rosenheim
# 8250446947   83607             Holzkirchen             Holzkirchen
# 8270001861   89143              Blaubeuren              Blaubeuren
# 8270007185   88515         Langenenslingen         Langenenslingen
# 8270054012   88471                Laupheim                Laupheim
# 8270110905   89233                 Neu-Ulm                 Neu-Ulm
# 8270204228   89129                Langenau                Langenau
# 8270241808   89150              Laichingen              Laichingen
# 8270289528   89150              Laichingen              Laichingen
# 8270315850   01665             Klipphausen             Klipphausen
# 8290004100   82205                Gilching                Gilching
# 8290050787   82431                  Kochel           Kochel a. See
# 8290056042   82319               Starnberg               Starnberg
# 8290073164   82467  Garmisch-Partenkirchen  Garmisch-Partenkirchen
# 8290102884   82237                Wörthsee                Wörthsee
# 8290119010   82538              Geretsried              Geretsried
# 8290126710   83646                Bad Tölz                Bad Tölz
# 8290132480   82319               Starnberg               Starnberg
# 8290212482   82380              Peißenberg              Peißenberg
# 8290235125   82538              Geretsried              Geretsried
# 8310005376   97450                Arnstein                Arnstein
# 8310007236   97437                 Haßfurt                 Haßfurt
# 8310025408   97332                 Volkach                 Volkach
# 8310081845   97907                 Hasloch                 Hasloch
# 8310149614   97274                 Leinach                 Leinach
# 8310156008   97483                 Eltmann                 Eltmann
# 8310162812   97723              Oberthulba              Oberthulba
# 8310182021   97854               Steinfeld               Steinfeld
#
# [549 rows x 10 columns]
